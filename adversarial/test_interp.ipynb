# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_path = "/Users/marchuertascompany/Documents/data/CEERS/DenseBasis/"
ceers_cat = pd.read_csv(data_path+"CEERS_DR05_adversarial_asinh_3filters_1122_4class_ensemble_v02_stellar_params_morphflag_delta_10points_DenseBasis_galfit_v051.csv")

# %%
plt.scatter(ceers_cat.logSFR100_50,ceers_cat.logSFR100_16,s=2)

# %%
SFR=ceers_cat.logSFR100_50.values
SFR16 = ceers_cat.logSFR100_16.values
nd = np.argsort(SFR, axis=0) 

SFR_sort = SFR[nd]
SFR16_sort = SFR16[nd]

# %%
intp = np.interp([-2],SFR_sort,SFR16_sort)
print(intp)
# Out:
# [-4.1535]
